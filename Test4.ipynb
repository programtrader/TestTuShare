# %%
import tushare as ts

df = ts.get_realtime_quotes('000581') #Single stock symbol

# %%
ts.get_hist_data('600848')
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# date
# 2017-11-07  28.60  29.37  28.98  28.42  173107.20          0.80      2.84
# 2017-11-06  28.67  28.74  28.18  27.76  150896.66          0.03      0.11
# 2017-11-03  28.86  29.62  28.15  28.03  279166.28         -2.30     -7.55
# 2017-11-02  31.80  31.80  30.45  30.45  312481.06         -3.38     -9.99
# 2017-11-01  33.85  34.34  33.83  33.10  232325.30         -0.61     -1.77
# 2017-10-31  32.62  35.22  34.44  32.20  361660.88          2.38      7.42
# 2017-10-30  32.56  34.40  32.06  31.85  337772.31         -1.05     -3.17
# 2017-10-27  31.45  33.20  33.11  31.45  333824.31          0.70      2.16
# 2017-10-26  29.30  32.70  32.41  28.92  501915.41          2.68      9.01
# 2017-10-25  27.86  30.45  29.73  27.54  328947.31          1.68      5.99
# 2017-10-24  28.20  28.75  28.05  27.22  313290.41         -1.74     -5.84
# 2017-10-23  29.00  31.16  29.79  28.90  466494.47          1.46      5.15
# ...

# %%
ts.get_h_data('002337')
# Out:
# [Getting data:]####
#             open  high  close   low      volume       amount
# date
# 2017-11-07  5.80  5.82   5.79  5.75   1823687.0   10532902.0
# 2017-11-06  5.73  5.80   5.79  5.70   1809032.0   10406768.0
# 2017-11-03  5.75  5.79   5.74  5.66   2137241.0   12234975.0
# 2017-11-02  5.82  5.82   5.76  5.76   1777600.0   10267208.0
# 2017-11-01  5.84  5.85   5.82  5.77   2248290.0   13042695.0
# 2017-10-31  5.71  5.82   5.81  5.71   1754701.0   10163261.0
# 2017-10-30  5.98  5.99   5.78  5.70   5655688.0   32844177.0
# 2017-10-27  6.10  6.10   5.99  5.99   5307510.0   32050186.0
# 2017-10-26  6.17  6.17   6.11  6.01   9968107.0   60536440.0
# 2017-10-25  6.10  6.27   6.26  6.06   4522045.0   27920691.0
# 2017-10-24  6.16  6.16   6.11  6.03   2889540.0   17580551.0
# 2017-10-23  6.10  6.15   6.15  6.09   1934609.0   11853761.0
# 2017-10-20  6.02  6.15   6.13  6.02   2204340.0   13455305.0
# 2017-10-19  6.14  6.15   6.05  6.03   3448940.0   20953032.0
# ...

# %%
df=ts.get_h_data('002337')
# Out:
# [Getting data:]####

# %%
df.to_dict(orient="")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-82ab4c9db319> in <module>()
# ----> 1 df.to_dict(orient="")
#
# /Users/pammeng/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in to_dict(self, orient)
#     910             return dict((k, v.to_dict()) for k, v in self.iterrows())
#     911         else:
# --> 912             raise ValueError("orient '%s' not understood" % orient)
#     913
#     914     def to_gbq(self, destination_table, project_id, chunksize=10000,
#
# ValueError: orient '' not understood

# %%
ts.get_today_all()
# Out:
# [Getting data:]############################################################
#         code   name  changepercent   trade    open    high     low  \
# 0     603999   读者传媒          1.474    8.95    8.84    8.95    8.74
# 1     603998   方盛制药          1.117   13.58   13.43   13.63   13.25
# 2     603997   继峰股份         -1.432   13.08   13.27   13.37   12.98
# 3     603996   中新科技         -2.142   18.73   19.05   19.25   18.54
# 4     603993   洛阳钼业          0.145    6.90    6.85    7.00    6.75
# 5     603991   至正股份          0.258   34.91   34.82   35.50   34.53
# 6     603990   麦迪科技         -2.656   38.49   39.40   39.58   38.17
# 7     603989   艾华集团          0.638   39.44   39.15   39.88   38.82
# 8     603988   中电电机          0.042   71.97   71.70   72.25   71.32
# 9     603987    康德莱          2.959   16.70   16.22   16.87   15.90
# 10    603986   兆易创新          0.000  163.12    0.00    0.00    0.00
# 11    603985   恒润股份         -0.320   43.60   43.78   43.78   43.23
# ...

# %%
df.to_dict(orient="record")
# Out:
# [{'amount': 24136421,
#   'changepercent': 1.474,
#   'code': u'603999',
#   'high': 8.95,
#   'low': 8.74,
#   'mktcap': 515520.0,
#   'name': u'\u8bfb\u8005\u4f20\u5a92',
#   'nmc': 206208.0,
#   'open': 8.84,
#   'pb': 3.091,
#   'per': 30.862,
#   'settlement': 8.82,
#   'trade': 8.95,
#   'turnoverratio': 1.18749,
#   'volume': 2735980},
#  {'amount': 24380060,
#   'changepercent': 1.117,
#   'code': u'603998',
#   'high': 13.63,
#   'low': 13.25,
#   'mktcap': 585211.72626,
#   'name': u'\u65b9\u76db\u5236\u836f',
#   'nmc': 365542.66476,
#   'open': 13.43,
#   'pb': 5.855,
#   'per': 84.875,
#   'settlement': 13.43,
#   'trade': 13.58,
#   'turnoverratio': 0.6754800000000001,
#   'volume': 1818240},
#  {'amount': 55297688,
#   'changepercent': -1.432,
#   'code': u'603997',
#   'high': 13.37,
#   'low': 12.98,
#   'mktcap': 824040.0,
#   'name': u'\u7ee7\u5cf0\u80a1\u4efd',
#   'nmc': 223668.0,
#   'open': 13.27,
#   'pb': 4.997,
#   'per': 22.169,
#   'settlement': 13.27,
# ...

# %%
import tushare as ts

df = ts.get_realtime_quotes('000581') #Single stock symbol
df[['code','name','price','bid','ask','volume','amount','time']]
# Out:
#      code  name   price     bid     ask volume      amount      time
# 0  000581  威孚高科  25.050  25.040  25.050  17300  433365.000  09:29:03

# %%
import tushare as ts

df = ts.get_realtime_quotes('600066') #Single stock symbol
df[['code','name','price','bid','ask','volume','amount','time']]
# Out:
#      code  name   price     bid     ask volume       amount      time
# 0  600066  宇通客车  24.480  24.480  24.500  47878  1171777.000  09:30:03

# %%
df.to_dict(orient="record")
# Out:
# [{'a1_p': u'24.500',
#   'a1_v': u'16',
#   'a2_p': u'24.570',
#   'a2_v': u'5',
#   'a3_p': u'24.590',
#   'a3_v': u'5',
#   'a4_p': u'24.620',
#   'a4_v': u'206',
#   'a5_p': u'24.650',
#   'a5_v': u'7',
#   'amount': u'1171777.000',
#   'ask': u'24.500',
#   'b1_p': u'24.480',
#   'b1_v': u'23',
#   'b2_p': u'24.460',
#   'b2_v': u'57',
#   'b3_p': u'24.450',
#   'b3_v': u'100',
#   'b4_p': u'24.420',
#   'b4_v': u'92',
#   'b5_p': u'24.410',
#   'b5_v': u'46',
#   'bid': u'24.480',
#   'code': u'600066',
#   'date': u'2017-11-08',
# 2017-10-30  25.13  25.33  25.25  24.43  117652.62          0.16      0.64
# 2017-10-27  25.36  25.68  25.09  25.02  106279.59         -0.22     -0.87
# 2017-10-26  25.00  26.04  25.31  24.95  209451.19          0.27      1.08
# 2017-10-25  25.27  25.30  25.04  24.83  132953.59         -0.28     -1.11
# 2017-10-24  24.08  25.35  25.32  24.08  281519.12          1.24      5.15
# 2017-10-23  25.50  25.50  24.08  23.91  247391.84         -1.40     -5.50
# ...

# %%
df.to_dict(orient="record")
# Out:
# [{'close': 24.670000000000002,
#   'high': 25.440000000000001,
#   'low': 24.399999999999999,
#   'ma10': 24.998000000000001,
#   'ma20': 25.050999999999998,
#   'ma5': 24.77,
#   'open': 24.82,
#   'p_change': -0.83999999999999997,
#   'price_change': -0.20999999999999999,
#   'turnover': 1.26,
#   'v_ma10': 142087.29999999999,
#   'v_ma20': 146106.42000000001,
#   'v_ma5': 151808.73000000001,
#   'volume': 239593.07999999999},
#  {'close': 24.879999999999999,
#   'high': 25.129999999999999,
#   'low': 24.550000000000001,
#   'ma10': 25.062999999999999,
#   'ma20': 25.059999999999999,
#   'ma5': 24.923999999999999,
#   'open': 24.789999999999999,
#   'p_change': 0.16,
#   'price_change': 0.040000000000000001,
#   'turnover': 0.56999999999999995,
#   'v_ma10': 146279.89999999999,
#   'v_ma20': 148473.17000000001,
#   'v_ma5': 122988.58,
#   'volume': 108741.36},
#  {'close': 24.84,
#   'high': 24.879999999999999,
#   'low': 24.25,
#   'ma10': 24.983000000000001,
# ...

# %%
df[['open']]#日期是索引
# Out:
#              open
# date
# 2017-11-07  24.82
# 2017-11-06  24.79
# 2017-11-03  24.61
# 2017-11-02  24.60
# 2017-11-01  25.61
# 2017-10-31  25.38
# 2017-10-30  25.13
# 2017-10-27  25.36
# 2017-10-26  25.00
# 2017-10-25  25.27
# 2017-10-24  24.08
# 2017-10-23  25.50
# 2017-10-20  25.68
# 2017-10-19  25.58
# 2017-10-18  24.90
# 2017-10-17  24.60
# 2017-10-16  24.83
# 2017-10-13  25.27
# 2017-10-12  24.69
# 2017-10-11  24.38
# 2017-10-10  25.20
# 2017-10-09  24.92
# 2017-09-29  24.65
# 2017-09-28  24.14
# 2017-09-27  23.40
# 2017-09-26  23.61
# 2017-09-25  23.51
# 2017-09-22  23.33
# 2017-09-21  23.75
# 2017-09-20  22.93
# ...           ...
# 2014-12-29  21.11
# 2014-12-26  21.00
# 2014-12-25  21.14
# 2014-12-24  20.74
# 2014-12-23  20.90
# 2014-12-22  21.25
# 2014-12-19  21.51
# 2014-12-18  21.61
# 2014-12-17  22.06
# 2014-12-16  21.75
# 2014-12-15  21.42
# 2014-12-12  21.65
# 2014-12-11  22.20
# 2014-12-10  21.21
# 2014-12-09  21.10
# 2014-12-08  20.39
# 2014-12-05  20.10
# ...

# %%
df.index.tolist()#可以将日期索引保存到
# Out:
# [u'2017-11-07',
#  u'2017-11-06',
#  u'2017-11-03',
#  u'2017-11-02',
#  u'2017-11-01',
#  u'2017-10-31',
#  u'2017-10-30',
#  u'2017-10-27',
#  u'2017-10-26',
#  u'2017-10-25',
#  u'2017-10-24',
#  u'2017-10-23',
#  u'2017-10-20',
#  u'2017-10-19',
#  u'2017-10-18',
#  u'2017-10-17',
#  u'2017-10-16',
#  u'2017-10-13',
#  u'2017-10-12',
#  u'2017-10-11',
#  u'2017-10-10',
#  u'2017-10-09',
#  u'2017-09-29',
#  u'2017-09-28',
#  u'2017-09-27',
#  u'2017-09-26',
#  u'2017-09-25',
#  u'2017-09-22',
#  u'2017-09-21',
#  u'2017-09-20',
#  u'2017-09-19',
#  u'2017-09-18',
#  u'2017-09-15',
#  u'2017-09-14',
#  u'2017-09-13',
#  u'2017-09-12',
#  u'2017-09-11',
#  u'2017-09-08',
#  u'2017-09-07',
#  u'2017-09-06',
#  u'2017-09-05',
#  u'2017-09-04',
#  u'2017-09-01',
#  u'2017-08-31',
#  u'2017-08-30',
#  u'2017-08-29',
#  u'2017-08-28',
#  u'2017-08-25',
#  u'2017-08-24',
#  u'2017-08-23',
#  u'2017-08-22',
#  u'2017-08-21',
#  u'2017-08-18',
#  u'2017-08-17',
#  u'2017-08-16',
# ...

# %%
import tushare as ts
df=ts.get_hist_data('600066', ktype='5') #获取5分钟k线数据

# %%
df.index.tolist()#可以将日期索引保存到
# Out:
# [u'2017-11-08 15:00:00',
#  u'2017-11-08 14:55:00',
#  u'2017-11-08 14:50:00',
#  u'2017-11-08 14:45:00',
#  u'2017-11-08 14:40:00',
#  u'2017-11-08 14:35:00',
#  u'2017-11-08 14:30:00',
#  u'2017-11-08 14:25:00',
#  u'2017-11-08 14:20:00',
#  u'2017-11-08 14:15:00',
#  u'2017-11-08 14:10:00',
#  u'2017-11-08 14:05:00',
#  u'2017-11-08 14:00:00',
#  u'2017-11-08 13:55:00',
#  u'2017-11-08 13:50:00',
#  u'2017-11-08 13:45:00',
#  u'2017-11-08 13:40:00',
#  u'2017-11-08 13:35:00',
#  u'2017-11-08 13:30:00',
#  u'2017-11-08 13:25:00',
#  u'2017-11-08 13:20:00',
#  u'2017-11-08 13:15:00',
#  u'2017-11-08 13:10:00',
#  u'2017-11-08 13:05:00',
#  u'2017-11-08 11:30:00',
#  u'2017-11-08 11:25:00',
#  u'2017-11-08 11:20:00',
#  u'2017-11-08 11:15:00',
#  u'2017-11-08 11:10:00',
#  u'2017-11-08 11:05:00',
#  u'2017-11-08 11:00:00',
#  u'2017-11-08 10:55:00',
#  u'2017-11-08 10:50:00',
#  u'2017-11-08 10:45:00',
#  u'2017-11-08 10:40:00',
#  u'2017-11-08 10:35:00',
#  u'2017-11-08 10:30:00',
# ...

# %%
sStr1= "woshisui"
sStr2= 'nishishui'
print cmp(sStr1,sStr2)
# Out:
# 1

# %%
sStr1= "w"
sStr2= 'w'
print cmp(sStr1,sStr2)
# Out:
# 0
